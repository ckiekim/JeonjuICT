# %% [markdown]
# # Matplotlib - 여러개의 그래프

# %%
# !apt-get install -y fonts-nanum > /dev/null
# !fc-cache -fv > /dev/null
# !rm -rf ~/.cache/matplotlib > /dev/null
# 런타임 > 런타임 다시 시작

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='NanumBarunGothic')

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)
def g(t):
    return np.sin(np.pi*t)

# %%
t1 = np.arange(0.0, 5.0, 0.01)
t2 = np.arange(0.0, 5.0, 0.01)

plt.subplot(221)            # 2 x 2, 그래프중 첫번째
plt.plot(t1, f(t1))
plt.subplot(2, 2, 2)
plt.plot(t2, g(t2))
plt.subplot(223)
plt.plot(t1, f(t1), 'r-')
plt.subplot(224)
plt.plot(t2, g(t2), 'r-')
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8a8a115d-28a4-4190-8306-fb87ca0b9c60" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8a8a115d-28a4-4190-8306-fb87ca0b9c60">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dog1.jpg to dog1.jpg

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-813cfbe0-d413-4e85-bb68-215ea918fa77" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-813cfbe0-d413-4e85-bb68-215ea918fa77">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dog2.jpg to dog2.jpg

# %%
from PIL import Image
dog1 = Image.open('dog1.jpg')
dog2 = Image.open('dog2.jpg')

plt.subplot(121)
plt.imshow(dog1)
plt.axis('off')

plt.subplot(122)
plt.imshow(dog2)
plt.axis('off')

plt.show()

# %% [markdown]
# ## Anscombe's Quartet

# %%
import seaborn as sns
ans = sns.load_dataset('anscombe')

fig, axes = plt.subplots(2, 2, figsize=(10,8), sharex=True, sharey=True)
for index, roman in enumerate(['I','II','III','IV']):
    ds = ans[ans.dataset == roman]
    ax = axes[index//2, index%2]
    ax.plot(ds.x, ds.y, 'o', markersize=10)
    ax.plot([3, 20], [4.5, 13], 'r-', lw=2)         # y = 0.5 * x + 3
    ax.set_title(f'Dataset {roman}')
fig.suptitle("Anscombe's Quartet", fontsize=16, y=1.02)
plt.tight_layout()
plt.show()
